# %% [markdown]
# <a href="https://colab.research.google.com/github/alineaprelini/Estat-stica/blob/main/Estat%C3%ADstica_b%C3%A1sica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import scipy
import seaborn as sns

# %% [markdown]
# ##**Fonte de dados**##
#
# https://ww2.ibge.gov.br/home/estatistica/populacao/trabalhoerendimento/pnad2015/microdados.shtm

# %%
df = pd.read_csv('dados.csv')
df
# Out:
#        UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0      11     0     23    8              12    800  1.603808
# 1      11     1     23    2              12   1150  1.739790
# 2      11     1     35    8              15    880  1.760444
# 3      11     0     46    2               6   3500  1.783158
# 4      11     1     47    8               9    150  1.690631
# ...    ..   ...    ...  ...             ...    ...       ...
# 76835  53     1     46    2              11    812  1.687030
# 76836  53     0     30    4               7   1500  1.792934
# 76837  53     0     32    8              12   1300  1.830587
# 76838  53     0     57    8               4   1500  1.726344
# 76839  53     0     38    8               4    900  1.658305
#
# [76840 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76840 entries, 0 to 76839
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   UF              76840 non-null  int64
#  1   Sexo            76840 non-null  int64
#  2   Idade           76840 non-null  int64
#  3   Cor             76840 non-null  int64
#  4   Anos de Estudo  76840 non-null  int64
#  5   Renda           76840 non-null  int64
#  6   Altura          76840 non-null  float64
# dtypes: float64(1), int64(6)
# memory usage: 4.1 MB
